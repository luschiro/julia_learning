# %%
using Pkg
Pkg.activate("env_learning")
# Out:
#   Activating project at `c:\Users\lucas\Desktop\code\Julia\julia_learning\env_learning`
# Status `C:\Users\lucas\Desktop\code\Julia\julia_learning\env_learning\Project.toml`
# ⌃ [336ed68f] CSV v0.10.11
#   [a93c6f00] DataFrames v1.6.1
#   [7073ff75] IJulia v1.24.2
# ⌅ [91a5bcdd] Plots v1.38.17
# ⌃ [c3e4b0f8] Pluto v0.19.27
# ⌃ [7f904dfe] PlutoUI v0.7.52
# Info Packages marked with ⌃ and ⌅ have new versions available, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated`

# %%
using Plots
using CSV
using DataFrames

# %%
CURRENTDIR = pwd()
file_name = "metamorphism_data.csv"
DATADIR = joinpath(CURRENTDIR, "metamorphism_data")
file_path = joinpath(DATADIR, "metamorphism_data.csv")

df = DataFrame(CSV.File(file_path))
# Out:
# UndefVarError: `CSV` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\lucas\Desktop\code\Julia\julia_learning\notebook_julia.ipynb:6

# %%
names(df)
# Out:
# 20-element Vector{String}:
#  "reference"
#  "year"
#  "sample"
#  "method"
#  "geological_unit"
#  "hue_domain"
#  "T"
#  "T_error"
#  "T_min"
#  "T_max"
#  "P"
#  "P_error"
#  "P_min"
#  "P_max"
#  "age"
#  "age_error"
#  "age_intepretation"
#  "age_method"
#  "plot_Tt"
#  "plot_PT"

# %%
size(df)
# Out:
# (148, 20)

# %%
dropmissing(df)
# Out:
# 1×20 DataFrame
#  Row │ reference         year   sample    method                            ge ⋯
#      │ String31          Int64  String31  String                            St ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Munha_et_al_2005   2005  -         GOSP+GASP+(Grt+Crd+Sil+Qtz)+grid  Pa ⋯
#                                                               16 columns omitted

# %% [markdown]
# T-t-plot file

# %%
CURRENTDIR = pwd()
file_name = "metamorphism_data.csv"
DATADIR = joinpath(CURRENTDIR, "metamorphism_data")
file_path = joinpath(DATADIR, "metamorphism_data.csv")
data = DataFrame(CSV.File(file_path))
data[1:5,:]
# Out:
# 5×20 DataFrame
#  Row │ reference            year     sample     method                         ⋯
#      │ String31?            Int64?   String31?  String?                        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Munha_et_al_2005        2005  -          GOSP+GASP+(Grt+Crd+Sil+Qtz)+gr ⋯
#    2 │ Queiroga_et_al_2006     2006  T123A      THERMOCALC
#    3 │ Queiroga_et_al_2006     2006  T191Xa     THERMOCALC
#    4 │ Queiroga_et_al_2006     2006  Q-14       THERMOCALC
#    5 │ missing              missing  missing    missing                        ⋯
#                                                               17 columns omitted

# %% [markdown]
# Script file

# %%
println("Loading OK")
println("First")
println("Secondddd")

function load_dir()
    println("We just entered a function!")
    CURRENT_DIR = pwd()
    return CURRENT_DIR
end

println("our current dir is ", load_dir())
x=[1,2,3]
y=x.^3

plot(x, y, seriestype=:scatter, yerr=1, xerr=0.5)
# Out:
# Loading OK
# First
# Secondddd
# We just entered a function!
# our current dir is c:\Users\lucas\Desktop\code\Julia\julia_learning
